# %% [markdown]
# # F1 2024 Model Evaluation
#
# This notebook loads predictions and creates quick diagnostics.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

model = 'hgb'
pred_path = f'data/metrics/predictions_{model}.parquet'
df = pd.read_parquet(pred_path)
df.head()

# %%
sns.set_theme(style='whitegrid')
plt.figure(figsize=(6, 6))
sns.scatterplot(x='LapTimeSeconds', y='pred', data=df, s=10, alpha=0.4)
min_val = min(df['LapTimeSeconds'].min(), df['pred'].min())
max_val = max(df['LapTimeSeconds'].max(), df['pred'].max())
plt.plot([min_val, max_val], [min_val, max_val], color='red', linewidth=1)
plt.title(f'Predicted vs Actual ({model})')
plt.xlabel('Actual Lap Time (s)')
plt.ylabel('Predicted Lap Time (s)')
plt.show()
